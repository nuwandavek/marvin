# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set_theme(style="darkgrid")
plt.rcParams["figure.figsize"] = (20,5)

# %%
df = pd.read_csv('../../data/processed_filtered/abstract/abstract_train_cross_predict_paraphrases.csv')

# %%
df.head()
# Out:
#                                                 text  label  \
# 0  We pinpoint the current challenges and opportu...      1
# 1  We consider the problem of designing scalable ...      1
# 2  Never to recover in the cities of Paris and Lo...      0
# 3  IF IT TURNS OUT TO NOT BE TRUE, THEN YOU HAVE ...      0
# 4  Multiple passes of an individual sample throug...      1
#
#                                         paraphrased1  \
# 0  we've identified the challenges and opportunit...
# 1  in order to reach a time-varying formation, we...
# 2                in Paris and London, never recover.
# 3  if it's not going to be TRUE, you're not gonna...
# 4  the non-determinist behavior of these techniqu...
#
#                                         paraphrased2  \
# 0  the challenges and opportunities facing the de...
# 1  in order to reach a time-varying formation, we...
# 2            in Paris and London, you won't recover.
# 3  if it's not going to be TRUE, you're not gonna...
# ...

# %%
df.shape
# Out:
# (81523, 13)

# %%
df.loc[df['label']==1,'pred_abstract_paraphrased3'].hist(bins=10)
# Out:
# <AxesSubplot:>
